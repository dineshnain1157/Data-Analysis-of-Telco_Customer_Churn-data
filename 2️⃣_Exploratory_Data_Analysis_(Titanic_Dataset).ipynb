# %% [markdown]
# <a href="https://colab.research.google.com/github/dineshnain1157/Data-Analysis-of-Telco_Customer_Churn-data/blob/main/2%EF%B8%8F%E2%83%A3_Exploratory_Data_Analysis_(Titanic_Dataset).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1.Import Libraries & Load Clean Data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)
df = pd.read_csv("cleaned_train-data.csv")
df.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  Sex_male  Embarked_Q  \
# 0         0       3  34.5      0      0   7.8292      True        True
# 1         1       3  47.0      1      0   7.0000     False       False
# 2         0       2  62.0      0      0   9.6875      True        True
# 3         0       3  27.0      0      0   8.6625      True       False
# 4         1       3  22.0      1      1  12.2875     False       False
#
#    Embarked_S
# 0       False
# 1        True
# 2       False
# 3        True
# 4        True

# %%
#2.Target Variable Distribution (Survived)
df['Survived'].value_counts()
sns.countplot(x='Survived', data=df)
plt.title("Survival Distribution")
plt.show()

# %%
#3.Survival Rate by Gender
sns.countplot(x='Sex_male', hue='Survived', data=df)
plt.title("Survival by Gender (0 = Female, 1 = Male)")
plt.show()

# %%
#4.Survival by Passenger Class
sns.countplot(x='Pclass', hue='Survived', data=df)
plt.title("Survival by Passenger Class")
plt.show()

# %%
#5.Age Distribution
plt.figure(figsize=(8,5))
sns.histplot(df['Age'], bins=30, kde=True)
plt.title("Age Distribution")
plt.show()

# %%
#6.Age vs Survival
plt.figure(figsize=(8,5))
sns.boxplot(x='Survived', y='Age', data=df)
plt.title("Age vs Survival")
plt.show()

# %%
#7.Fare Distribution
plt.figure(figsize=(8,5))
sns.histplot(df['Fare'], bins=30, kde=True)
plt.title("Fare Distribution")
plt.show()

# %%
#8.Fare vs Survival
plt.figure(figsize=(8,5))
sns.boxplot(x='Survived', y='Fare', data=df)
plt.title("Fare vs Survival")
plt.show()

# %%
#9.Family Size Analysis
df['FamilySize'] = df['SibSp'] + df['Parch'] + 1
sns.barplot(x='FamilySize', y='Survived', data=df)
plt.title("Family Size vs Survival Rate")
plt.show()

# %%
#10.Embarkation Port vs Survival
sns.countplot(x='Embarked_S', hue='Survived', data=df)
plt.title("Survival by Embarkation Port (S vs Others)")
plt.show()

# %%
#11.Correlation Heatmap
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
### 🔑 Key Insights from EDA
##- Females had a much higher survival rate than males
##- First-class passengers survived more
##- Higher fare correlates with higher survival probability
##- Smaller families had better survival chances
##- Socio-economic status strongly influenced survival
